# %% [markdown]
# # Laboratorio 3 - Segmentacion por Instancias
#
# Nombre Completo: Juan Carlos Cerón Lombana
# ID UAO: 2235516
#
# Nombre Completo: Danny Mauricio Montero
# ID UAO: 2244168

# %% [markdown]
# ###Instalación de librerías

# %%
# %pip install tensorflow opencv-python-headless matplotlib roboflow mrcnn
# Out:
# Collecting tensorflowNote: you may need to restart the kernel to use updated packages.
#
#   Using cached tensorflow-2.18.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting roboflow
#   Using cached roboflow-1.1.50-py3-none-any.whl.metadata (9.7 kB)
# Collecting mrcnn
#   Using cached mrcnn-0.2.tar.gz (51 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tensorflow-intel==2.18.0 (from tensorflow)
#   Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached protobuf-5.29.1-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting setuptools (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions>=3.6.6 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached wrapt-1.17.0-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached grpcio-1.68.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached keras-3.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy<2.1.0,>=1.26.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Collecting h5py>=3.11.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached h5py-3.12.1-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.55.3-cp312-cp312-win_amd64.whl.metadata (168 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: pillow>=8 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting certifi (from roboflow)
#   Using cached certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: python-dotenv in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filetype in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (1.2.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow)
#   Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: colorama in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Using cached optree-0.13.1-cp312-cp312-win_amd64.whl.metadata (48 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached tensorflow-2.18.0-cp312-cp312-win_amd64.whl (7.5 kB)
# Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl (390.3 MB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached roboflow-1.1.50-py3-none-any.whl (81 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.55.3-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Using cached numpy-2.0.2-cp312-cp312-win_amd64.whl (15.6 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.68.1-cp312-cp312-win_amd64.whl (4.4 MB)
# Using cached h5py-3.12.1-cp312-cp312-win_amd64.whl (3.0 MB)
# Using cached keras-3.7.0-py3-none-any.whl (1.2 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl (127 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached protobuf-5.29.1-cp310-abi3-win_amd64.whl (434 kB)
# Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Using cached setuptools-75.6.0-py3-none-any.whl (1.2 MB)
# Using cached termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached wrapt-1.17.0-cp312-cp312-win_amd64.whl (38 kB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached namex-0.0.8-py3-none-any.whl (5.8 kB)
# Using cached optree-0.13.1-cp312-cp312-win_amd64.whl (292 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: mrcnn
#   Building wheel for mrcnn (pyproject.toml): started
#   Building wheel for mrcnn (pyproject.toml): finished with status 'done'
#   Created wheel for mrcnn: filename=mrcnn-0.2-py3-none-any.whl size=54917 sha256=55d0ab8ab85157fbce792fffe6f8870d90e7982214ef992f896d7f8d9249e610
#   Stored in directory: c:\users\tatiana\appdata\local\pip\cache\wheels\b7\db\29\56f408f3de99a3a51d37bf2e9ac3b67fdafa32a9bf8054cc0a
# Successfully built mrcnn
# Installing collected packages: namex, mrcnn, libclang, flatbuffers, wrapt, wheel, typing-extensions, termcolor, tensorboard-data-server, setuptools, protobuf, opt-einsum, numpy, mdurl, MarkupSafe, markdown, kiwisolver, idna, grpcio, google-pasta, gast, fonttools, cycler, charset-normalizer, certifi, absl-py, werkzeug, requests, optree, opencv-python-headless, ml-dtypes, markdown-it-py, h5py, contourpy, astunparse, tensorboard, rich, requests-toolbelt, matplotlib, roboflow, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# Successfully installed MarkupSafe-3.0.2 absl-py-2.1.0 astunparse-1.6.3 certifi-2024.12.14 charset-normalizer-3.4.0 contourpy-1.3.1 cycler-0.12.1 flatbuffers-24.3.25 fonttools-4.55.3 gast-0.6.0 google-pasta-0.2.0 grpcio-1.68.1 h5py-3.12.1 idna-3.7 keras-3.7.0 kiwisolver-1.4.7 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 matplotlib-3.10.0 mdurl-0.1.2 ml-dtypes-0.4.1 mrcnn-0.2 namex-0.0.8 numpy-2.0.2 opencv-python-headless-4.10.0.84 opt-einsum-3.4.0 optree-0.13.1 protobuf-5.29.1 requests-2.32.3 requests-toolbelt-1.0.0 rich-13.9.4 roboflow-1.1.50 setuptools-75.6.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-2.18.0 tensorflow-intel-2.18.0 termcolor-2.5.0 typing-extensions-4.12.2 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.0

# %%
# %pip install scikit-image
# %pip install roboflow
# Out:
# Requirement already satisfied: scikit-image in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.2 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (11.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (2024.12.12)
# Requirement already satisfied: packaging>=21 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: roboflow in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (1.1.50)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: certifi in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (2024.12.14)
# Requirement already satisfied: idna==3.7 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (11.0.0)
# Requirement already satisfied: python-dateutil in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib->roboflow) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from requests->roboflow) (3.4.0)

# %% [markdown]
# ###Descargamos el Dataset desde Roboflow

# %%
# %pip install roboflow --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import roboflow
import os

# Inicializar el objeto de Roboflow
rf = roboflow.Roboflow(api_key="ePKlGvWr1xfAErIigf0D")

# Obtener el proyecto y la versión
project = rf.workspace("jcceron").project("laboratorio_3")
version = project.version(2)

# Definir una ruta para la descarga
output_dir = "C:\\datasets\\laboratorio_3"
os.makedirs(output_dir, exist_ok=True)

# Descargar el dataset en formato YOLOv8
dataset = version.download("yolov8", location=output_dir, overwrite=True)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in C:\datasets\laboratorio_3 to yolov8:: 100%|██████████| 6844/6844 [00:01<00:00, 6817.21it/s]
# Extracting Dataset Version Zip to C:\datasets\laboratorio_3 in yolov8:: 100%|██████████| 260/260 [00:00<00:00, 994.72it/s]

# %% [markdown]
# ## Investigación y Explicación de Métricas

# %% [markdown]
# ### Métricas para detección y segmentación por instancias
#
# - Precisión (Accuracy)
#
# La precisión es la proporción de predicciónes correctas entre el total de predicciones realizadas.  Esta métrica puede ser engañosa en datasets desbalanceados.
# Esta métrica se obtiene con:
#
# Accuracy = Número de predicciones correctas/ Número total de predicciones.
#
# - Índice de similitud de Jaccard (IoU - Intersection over Union)
# IoU es una métrica que mide la coincidencia entre el bounding box predicho y el bounding box real.
# Esta métrica se obteine con:
#
# IoU = área de intersección / área de unión.
#
# Su interpretación corresponde a:
# 1 significa una coincidencia perfecta. Generalmente, se considera una predicción correcta si el IoU es mayor que 0.5.
#
# - AP (Average Precisión)
# Se calcula con el promedio de precisión calculado en diferentes umbrales de IoU.
#
# - mAP (mean Average Precisión)
# Es el promedio de AP para todas las clases del dataset utilizado

# %% [markdown]
# ###4. Segmentación por Instancias de al menos dos objetos distintos
#
# - Creación del Dataset
# Se realizó el dataset a través de la aplicación Roboflow, donde realizamos un etiquetado manual, a través de esta aplicación se creó y etiquetó un dataset propio con más de 20 imágenes por clase correspondiente a animales de granja (caballo, gallina, perro, gato)
#
# - Entrenamiento
# Se usará Mask R-CNN para entrenar el modelo de segmentación.

# %%
# %pip install opencv-python-headless
# Out:
# Requirement already satisfied: opencv-python-headless in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from opencv-python-headless) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os

# Definir la ruta a la carpeta de imágenes exportadas desde Roboflow
image_folder = "C:/datasets/Laboratorio_3/train/images"

# Verificar si la carpeta existe
if not os.path.exists(image_folder):
    print(f"Error: La carpeta '{image_folder}' no existe.")
else:
    # Obtener una lista de todas las imágenes en la carpeta
    image_files = [f for f in os.listdir(image_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

    # Verificar si hay imágenes en la carpeta
    if not image_files:
        print(f"No se encontraron imágenes en la carpeta '{image_folder}'.")
    else:
        # Verificar el tamaño de las primeras 5 imágenes
        for image_file in image_files[:5]:
            image_path = os.path.join(image_folder, image_file)
            image = cv2.imread(image_path)
            if image is not None:
                height, width, _ = image.shape
                print(f"{image_file}: {width}x{height} píxeles")
            else:
                print(f"Error: No se pudo cargar la imagen '{image_file}'. Verifica que el archivo no esté corrupto.")
# Out:
# 1213_jpg.rf.ad2f9c775d4fe6a0f290c06566af5c82.jpg: 640x640 píxeles
# 1213_jpg.rf.ceb687d6cf69eb24f275c9715e69a376.jpg: 640x640 píxeles
# 1213_jpg.rf.f4494f8b1a067d8d8a01ec714a541974.jpg: 640x640 píxeles
# 1219_jpeg.rf.077de2f66df2ed9d7def4769563c8df0.jpg: 640x640 píxeles
# 1219_jpeg.rf.9d3b46748108893ea0f86e59fb86c7e1.jpg: 640x640 píxeles

# %%
# %pip install ultralytics
# %pip show ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (8.3.51)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (2.5.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (6.1.0)
# Requirement already satisfied: py-cpuinfo in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from ultralytics) (2.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: setuptools in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from torch>=1.8.0->ultralytics) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tatiana\documents\github\laboratorio3_vc\lab3vc\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Name: ultralytics
# Version: 8.3.51
# Summary: Ultralytics YOLO 🚀 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://ultralytics.com
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: c:\Users\Tatiana\Documents\GitHub\Laboratorio3_VC\lab3vc\Lib\site-packages
# Requires: matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, torch, torchvision, tqdm, ultralytics-thop
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.3.51
# Summary: Ultralytics YOLO 🚀 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://ultralytics.com
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: c:\Users\Tatiana\Documents\GitHub\Laboratorio3_VC\lab3vc\Lib\site-packages
# Requires: matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, torch, torchvision, tqdm, ultralytics-thop
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.51  Python-3.12.8 torch-2.5.1+cpu CPU (Intel Core(TM) i5-8250U 1.60GHz)
# Setup complete  (8 CPUs, 7.9 GB RAM, 235.5/237.2 GB disk)

# %%
from ultralytics import YOLO
import os

# %% [markdown]
# TASK (si no se coloca la infiere del dataset) --> detect, segment, classify, pose.
# MODE --> train, val, predict, track (obligatorio)
# ARGS --> por ejemplo tamñao de imagen imgsz=320.

# %%
HOME = os.getcwd()
print(HOME)
ubicacion = HOME
print(f"Mi ubicación actual es: {ubicacion}")
# Out:
# c:\Users\Tatiana\Documents\GitHub\Laboratorio3_VC
# Mi ubicación actual es: c:\Users\Tatiana\Documents\GitHub\Laboratorio3_VC

# %%
ubicacion_data = {dataset.location}
print(ubicacion_data)
# Out:
# {'C:\\datasets\\laboratorio_3'}

# %%
# !yolo task=segment mode=train model=yolov8n-seg.pt data={dataset.location}/data.yaml epochs=20 imgsz=640 verbose=True

#!yolo task=segment mode=train model=yolov8n-seg.pt data={dataset.location}/data.yaml epochs=50 imgsz=640 --stream

#python train.py task=detect mode=train
# Out:
# ^C

# %%
from IPython.display import Image, display

# Mostrar la matriz de confusión
Image(filename=f'{HOME}/runs/segment/train/confusion_matrix.png', width=600)

# %%
# Mostrar resultados de entrenamiento
Image(filename=f'{HOME}/runs/segment/train/results.png', width=600)

# %% [markdown]
# -Detección

# %%
# !pip install opencv-python
# !pip show opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from opencv-python) (2.0.2)
# Name: opencv-python
# Version: 4.10.0.84
# Summary: Wrapper package for OpenCV python bindings.
# Home-page: https://github.com/opencv/opencv-python
# Author:
# Author-email:
# License: Apache 2.0
# Location: c:\Python312\Lib\site-packages
# Requires: numpy
# Required-by: ultralytics

# %%
#Prueba de activación de la cámara

import cv2
import matplotlib.pyplot as plt

# Capturar video desde la cámara
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: No se pudo abrir la cámara.")
else:
    ret, frame = cap.read()
    if ret:
        # Convertir de BGR a RGB para matplotlib
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Mostrar la imagen con matplotlib
        plt.imshow(frame_rgb)
        plt.title('Prueba de OpenCV con matplotlib')
        plt.axis('off')
        plt.show()
    else:
        print("Error: No se pudo capturar el frame.")

cap.release()

# %% [markdown]
# ### Procesamiento clásico de Imagenes
# Se realizan dos tipos de procesamiento de las imágenes al código anterior.
# - Filtro de Detección de bordes (Sobel)
# - Cambio de Color a Escala de Grises

# %%
#Instalamos la versión estándar de OpenCV, desinstalando OpenCV-python-headless
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from opencv-python) (2.0.2)

# %%
pip list | findstr opencv
# Out:
# opencv-python             4.10.0.84
# opencv-python-headless    4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
import numpy as np
import os

# Obtener la ruta actual de trabajo
HOME = os.getcwd()

# Cargar el modelo YOLOv8 previamente entrenado después del Data Augmentation
model_path = f"{HOME}/runs/segment/train/weights/best.pt"  # Asegúrate de que esta ruta es correcta
model = YOLO(model_path)

# Iniciar la captura de video desde la cámara (0 = cámara por defecto)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: No se pudo abrir la cámara.")
    exit()

# Configurar matplotlib para modo interactivo
plt.ion()
fig, ax = plt.subplots(figsize=(10, 6))

# Bucle para capturar video continuamente
while True:
    # Capturar un frame de la cámara
    ret, frame = cap.read()
    if not ret:
        print("Error: No se pudo capturar el frame.")
        break

    # Redimensionar el frame para garantizar un tamaño compatible con el modelo (por ejemplo, 640x640)
    resized_frame = cv2.resize(frame, (640, 640))

    # Realizar la predicción de segmentación
    results = model.predict(resized_frame, conf=0.25, iou=0.5, verbose=False)

    # Extraer la cantidad de instancias detectadas
    num_instances = len(results[0].boxes)
    print(f"Cantidad de instancias detectadas: {num_instances}")

    # Dibujar las segmentaciones en el frame
    annotated_frame = results[0].plot()

    # Mostrar el frame anotado con OpenCV
    cv2.imshow("Segmentación en Tiempo Real", annotated_frame)

    # Salir del bucle con la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la cámara y cerrar las ventanas
cap.release()
cv2.destroyAllWindows()
plt.close()
# Out:
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# ...
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1

# %% [markdown]
# ###Sección de Data Aumentation

# %%
# !pip install albumentations opencv-python-headless
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting albumentations
#   Downloading albumentations-1.4.22-py3-none-any.whl.metadata (33 kB)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from albumentations) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: PyYAML in c:\python312\lib\site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from albumentations) (2.9.2)
# Collecting albucore==0.0.21 (from albumentations)
#   Downloading albucore-0.0.21-py3-none-any.whl.metadata (5.3 kB)
# Collecting eval-type-backport (from albumentations)
#   Using cached eval_type_backport-0.2.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.21->albumentations)
#   Downloading stringzilla-3.11.1-cp312-cp312-win_amd64.whl.metadata (81 kB)
# Collecting simsimd>=5.9.2 (from albucore==0.0.21->albumentations)
#   Downloading simsimd-6.2.1-cp312-cp312-win_amd64.whl.metadata (67 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from pydantic>=2.9.2->albumentations) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\jcceron.uao\appdata\roaming\python\python312\site-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Downloading albumentations-1.4.22-py3-none-any.whl (258 kB)
# Downloading albucore-0.0.21-py3-none-any.whl (12 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Using cached eval_type_backport-0.2.0-py3-none-any.whl (5.9 kB)
# Downloading simsimd-6.2.1-cp312-cp312-win_amd64.whl (87 kB)
# Downloading stringzilla-3.11.1-cp312-cp312-win_amd64.whl (79 kB)
# Installing collected packages: stringzilla, simsimd, opencv-python-headless, eval-type-backport, albucore, albumentations
# Successfully installed albucore-0.0.21 albumentations-1.4.22 eval-type-backport-0.2.0 opencv-python-headless-4.10.0.84 simsimd-6.2.1 stringzilla-3.11.1

# %% [markdown]
# - Realizamos diferentes transformaciones para aumentar nuestra dataset

# %%
import cv2
import os
import albumentations as A
from albumentations.pytorch import ToTensorV2
import numpy as np
import matplotlib.pyplot as plt

# Definir la ruta de las imágenes del dataset
input_dir = "C:\\datasets\\laboratorio_3\\train\\images"
output_dir = "C:\\datasets\\laboratorio_3\\augmented_images"
os.makedirs(output_dir, exist_ok=True)

# Definir transformaciones de Data Augmentation
transform = A.Compose([
    A.HorizontalFlip(p=0.5),               # Voltear horizontalmente con probabilidad del 50%
    A.VerticalFlip(p=0.2),                 # Voltear verticalmente con probabilidad del 20%
    A.RandomBrightnessContrast(p=0.2),     # Cambiar brillo y contraste
    A.Rotate(limit=30, p=0.5),             # Rotar hasta 30 grados
    A.GaussianBlur(p=0.2),                 # Aplicar desenfoque gaussiano
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=15, p=0.5),
    A.RandomCrop(width=512, height=512, p=0.5),  # Recortar aleatoriamente
    ToTensorV2()                           # Convertir a tensor
])

# Función para aplicar Data Augmentation
def augment_images(input_dir, output_dir, num_augmented=5):
    for img_name in os.listdir(input_dir):
        if img_name.endswith(".jpg") or img_name.endswith(".png"):
            img_path = os.path.join(input_dir, img_name)
            image = cv2.imread(img_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            for i in range(num_augmented):
                augmented = transform(image=image)
                augmented_image = augmented['image'].numpy().transpose(1, 2, 0)  # Convertir a formato HWC

                # Guardar la imagen aumentada
                output_path = os.path.join(output_dir, f"{img_name.split('.')[0]}_aug_{i}.jpg")
                plt.imsave(output_path, augmented_image)

            print(f"Imágenes aumentadas guardadas para: {img_name}")

# Aplicar Data Augmentation
augment_images(input_dir, output_dir, num_augmented=5)
# Out:
# Imágenes aumentadas guardadas para: OIP-8Wfr35q2NvycyPXuDDUhiAHaFd_jpeg.rf.ffcb2ff0b8aee5c3203e05d06821058c.jpg
# Imágenes aumentadas guardadas para: OIP-BpkY5Bfup8-ndUY-wkQytQHaFh_jpeg.rf.2653441f6e8005dc30c8826e0b126190.jpg
# Imágenes aumentadas guardadas para: OIP-BpkY5Bfup8-ndUY-wkQytQHaFh_jpeg.rf.ad48ffe9603d76680fcdbdff306f5334.jpg
# Imágenes aumentadas guardadas para: OIP-BpkY5Bfup8-ndUY-wkQytQHaFh_jpeg.rf.e0912d77dda5b1267bb32b3ea898c3e6.jpg
# Imágenes aumentadas guardadas para: OIP-_g_M1TKsvau0Um-NVpZjCgHaE7_jpeg.rf.2638facfa70e2542db118639ba0ef5b5.jpg
# Imágenes aumentadas guardadas para: OIP-_g_M1TKsvau0Um-NVpZjCgHaE7_jpeg.rf.821f2747ab76378887a508e1834081e2.jpg
# Imágenes aumentadas guardadas para: OIP-_g_M1TKsvau0Um-NVpZjCgHaE7_jpeg.rf.c5806b53c628d8833815a530acb0a238.jpg
# Imágenes aumentadas guardadas para: OIP-_iuGTvzHiVMaxl_jVCgbzgHaKH_jpeg.rf.a83714b654716497c8dc9d9f57acbf9a.jpg
# Imágenes aumentadas guardadas para: OIP-_iuGTvzHiVMaxl_jVCgbzgHaKH_jpeg.rf.bcca238c641dbdfa2057f4a48c012299.jpg
# Imágenes aumentadas guardadas para: OIP-_iuGTvzHiVMaxl_jVCgbzgHaKH_jpeg.rf.fa62a885a89b34792a9b50220c246d38.jpg

# %% [markdown]
# ##Visualizamos las imágenes aumentadas

# %%
import random

# Visualizar imágenes aumentadas
def visualize_augmented_images(output_dir, num_images=5):
    augmented_images = random.sample(os.listdir(output_dir), num_images)

    plt.figure(figsize=(15, 15))
    for i, img_name in enumerate(augmented_images):
        img_path = os.path.join(output_dir, img_name)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.subplot(2, num_images, i + 1)
        plt.imshow(img)
        plt.title(img_name)
        plt.axis("off")
    plt.show()

# Visualizar 5 imágenes aumentadas
visualize_augmented_images(output_dir, num_images=5)

# %% [markdown]
# - Incluimos el Data Aumentation en el Entrenaimiento con YOLOv8

# %%
# !yolo task=segment mode=train model=yolov8n-seg.pt data={dataset.location}/data_da.yaml epochs=30 imgsz=640 verbose=True
# Out:
# zero-size array to reduction operation maximum which has no identity
# C:\Users\jcceron.uao\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\tasks.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# New https://pypi.org/project/ultralytics/8.3.51 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.12.6 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-12450H)
# engine\trainer: task=segment, mode=train, model=yolov8n-seg.pt, data=C:\datasets\laboratorio_3/data_da.yaml, epochs=30, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\segment\train8
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1004860  ultralytics.nn.modules.head.Segment          [4, 32, 64, [64, 128, 256]]
# YOLOv8n-seg summary: 261 layers, 3264396 parameters, 3264380 gradients, 12.1 GFLOPs
#
# Transferred 381/417 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\segment\train8', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# C:\Users\jcceron.uao\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\trainer.py:238: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = amp.GradScaler(enabled=self.amp)
#
# train: Scanning C:\datasets\laboratorio_3\augmented_images...:   0%|          | 0/180 [00:00<?, ?it/s]
# train: Scanning C:\datasets\laboratorio_3\augmented_images... 0 images, 180 backgrounds, 0 corrupt: 100%|██████████| 180/180 [00:00<00:00, 3247.79it/s]
# train: WARNING  No labels found in C:\datasets\laboratorio_3\augmented_images.cache. See https://docs.ultralytics.com/datasets/detect for dataset formatting guidance.
# train: New cache created: C:\datasets\laboratorio_3\augmented_images.cache
# WARNING  No labels found in C:\datasets\laboratorio_3\augmented_images.cache, training may not work correctly. See https://docs.ultralytics.com/datasets/detect for dataset formatting guidance.
# C:\Users\jcceron.uao\AppData\Roaming\Python\Python312\site-packages\albumentations\core\composition.py:243: UserWarning: Got processor for bboxes, but no transform to process it.
#   self._set_keys()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
# val: Scanning C:\datasets\laboratorio_3\valid\labels.cache... 11 images, 0 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# val: Scanning C:\datasets\laboratorio_3\valid\labels.cache... 11 images, 0 backgrounds, 0 corrupt: 100%|██████████| 11/11 [00:00<?, ?it/s]
# Plotting labels to runs\segment\train8\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\segment\train8
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#
#   0%|          | 0/12 [00:00<?, ?it/s]
#        1/30         0G          0          0      124.3          0          0        640:   0%|          | 0/12 [00:19<?, ?it/s]
#        1/30         0G          0          0      124.3          0          0        640:   8%|▊         | 1/12 [00:19<03:31, 19.20s/it]
#        1/30         0G          0          0      124.3          0          0        640:   8%|▊         | 1/12 [00:25<03:31, 19.20s/it]
#        1/30         0G          0          0      124.3          0          0        640:  17%|█▋        | 2/12 [00:25<01:56, 11.63s/it]
#        1/30         0G          0          0      124.2          0          0        640:  17%|█▋        | 2/12 [00:31<01:56, 11.63s/it]
#        1/30         0G          0          0      124.2          0          0        640:  25%|██▌       | 3/12 [00:31<01:19,  8.88s/it]
#        1/30         0G          0          0      124.1          0          0        640:  25%|██▌       | 3/12 [00:36<01:19,  8.88s/it]
#        1/30         0G          0          0      124.1          0          0        640:  33%|███▎      | 4/12 [00:36<00:59,  7.39s/it]
#        1/30         0G          0          0      123.9          0          0        640:  33%|███▎      | 4/12 [00:41<00:59,  7.39s/it]
#        1/30         0G          0          0      123.9          0          0        640:  42%|████▏     | 5/12 [00:41<00:46,  6.58s/it]
#        1/30         0G          0          0      123.7          0          0        640:  42%|████▏     | 5/12 [00:46<00:46,  6.58s/it]
#        1/30         0G          0          0      123.7          0          0        640:  50%|█████     | 6/12 [00:46<00:36,  6.12s/it]
#        1/30         0G          0          0      123.5          0          0        640:  50%|█████     | 6/12 [00:51<00:36,  6.12s/it]
#        1/30         0G          0          0      123.5          0          0        640:  58%|█████▊    | 7/12 [00:51<00:28,  5.74s/it]
#        1/30         0G          0          0      123.2          0          0        640:  58%|█████▊    | 7/12 [00:56<00:28,  5.74s/it]
#        1/30         0G          0          0      123.2          0          0        640:  67%|██████▋   | 8/12 [00:56<00:22,  5.60s/it]
#        1/30         0G          0          0        123          0          0        640:  67%|██████▋   | 8/12 [01:02<00:22,  5.60s/it]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.75s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.76s/it]
#                    all         11         20   0.000621       0.25   0.000668   0.000168   0.000123     0.0625   0.000148   1.48e-05
#
# 30 epochs completed in 0.495 hours.
# Optimizer stripped from runs\segment\train8\weights\last.pt, 6.8MB
# Optimizer stripped from runs\segment\train8\weights\best.pt, 6.8MB
#
# Validating runs\segment\train8\weights\best.pt...
# Ultralytics YOLOv8.0.196  Python-3.12.6 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-12450H)
# YOLOv8n-seg summary (fused): 195 layers, 3258844 parameters, 0 gradients, 12.0 GFLOPs
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/1 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
#                    all         11         20     0.0088      0.938      0.166     0.0915     0.0088      0.938      0.151     0.0905
#                caballo         11          4    0.00431          1      0.254      0.129    0.00431          1      0.205     0.0901
#                gallina         11          6     0.0192          1     0.0867     0.0609     0.0192          1     0.0739     0.0498
#                   gato         11          4    0.00209       0.75     0.0225    0.00679    0.00209       0.75     0.0189     0.0055
#                  perro         11          6    0.00958          1      0.303       0.17    0.00958          1      0.306      0.217
# Speed: 1.4ms preprocess, 96.7ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs\segment\train8
#  Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# - Visulalización en tiempo real despúes del Data Aumentation

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
import numpy as np
import os

# Obtener la ruta actual de trabajo
HOME = os.getcwd()

# Cargar el modelo YOLOv8 previamente entrenado después del Data Augmentation
model_path = f"{HOME}/runs/segment/train/weights/best.pt"  # Asegúrate de que esta ruta es correcta
model = YOLO(model_path)

# Iniciar la captura de video desde la cámara (0 = cámara por defecto)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: No se pudo abrir la cámara.")
    exit()

# Configurar matplotlib para modo interactivo
plt.ion()
fig, ax = plt.subplots(figsize=(10, 6))

# Bucle para capturar video continuamente
while True:
    # Capturar un frame de la cámara
    ret, frame = cap.read()
    if not ret:
        print("Error: No se pudo capturar el frame.")
        break

    # Redimensionar el frame para garantizar un tamaño compatible con el modelo (por ejemplo, 640x640)
    resized_frame = cv2.resize(frame, (640, 640))

    # Realizar la predicción de segmentación
    results = model.predict(resized_frame, conf=0.25, iou=0.5, verbose=False)

    # Extraer la cantidad de instancias detectadas
    num_instances = len(results[0].boxes)
    print(f"Cantidad de instancias detectadas: {num_instances}")

    # Dibujar las segmentaciones en el frame
    annotated_frame = results[0].plot()

    # Mostrar el frame anotado con OpenCV
    cv2.imshow("Segmentación en Tiempo Real", annotated_frame)

    # Salir del bucle con la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la cámara y cerrar las ventanas
cap.release()
cv2.destroyAllWindows()
plt.close()
# Out:
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# ...
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 4
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 3
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 2
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 0
# Cantidad de instancias detectadas: 1
# Cantidad de instancias detectadas: 1
